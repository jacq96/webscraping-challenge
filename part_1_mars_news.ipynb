# %% [markdown]
# # Module 12 Challenge
# ## Deliverable 1: Scrape Titles and Preview Text from Mars News

# %%
# Import Selenium/Spinter and BeautifulSoup
from splinter import Browser
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from bs4 import BeautifulSoup
import os

current_directory = os.getcwd()
chromedriver_path = os.path.join(current_directory, '..', 'chromedriver', 'chromedriver.exe')

# Set up Chrome options
chrome_options = webdriver.ChromeOptions()
# Uncomment the line below if you want the browser to run headless
#chrome_options.add_argument("--headless")


# Initialize the Chrome WebDriver with the updated method
service = Service(executable_path=chromedriver_path)
browser = webdriver.Chrome(service=service, options=chrome_options)

# %%
browser = Browser('chrome')

# %% [markdown]
# ### Step 1: Visit the Website
#
# 1. Use automated browsing to visit the [Mars news site](https://static.bc-edx.com/data/web/mars_news/index.html). Inspect the page to identify which elements to scrape.
#
#       > **Hint** To identify which elements to scrape, you might want to inspect the page by using Chrome DevTools.

# %%
# Visit the Mars news site
url = 'https://static.bc-edx.com/data/web/mars_news/index.html'
browser.get(url)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 3
#       1 # Visit the Mars news site
#       2 url = 'https://static.bc-edx.com/data/web/mars_news/index.html'
# ----> 3 browser.get(url)
#
# AttributeError: 'WebDriver' object has no attribute 'get'

# %% [markdown]
# ### Step 2: Scrape the Website
#
# Create a Beautiful Soup object and use it to extract text elements from the website.

# %%
# Create a Beautiful Soup object
html = browser.page_source
soup = BeautifulSoup(html, 'html.parser')

# %%
# Extract all the text elements
text_elements = soup.find_all(string=True)
for text in text_elements:
    print(text)

# %% [markdown]
# ### Step 3: Store the Results
#
# Extract the titles and preview text of the news articles that you scraped. Store the scraping results in Python data structures as follows:
#
# * Store each title-and-preview pair in a Python dictionary. And, give each dictionary two keys: `title` and `preview`. An example is the following:
#
#   ```python
#   {'title': "NASA's MAVEN Observes Martian Light Show Caused by Major Solar Storm",
#    'preview': "For the first time in its eight years orbiting Mars, NASA’s MAVEN mission witnessed two different types of ultraviolet aurorae simultaneously, the result of solar storms that began on Aug. 27."
#   }
#   ```
#
# * Store all the dictionaries in a Python list.
#
# * Print the list in your notebook.

# %%
# Create an empty list to store the dictionaries
text_data = []
for text in text_elements:
    text_data.append({'text': text})

# %%
# Loop through the text elements
for i in range(len(text_elements)-1):
# Extract the title and preview text from the elements
    title = text_elements[i].strip()
    preview = text_elements[i+1].strip()
    
# Store each title and preview pair in a dictionary
    title_prev_dict = {'title': title, 'preview': preview}
# Add the dictionary to the list
    text_data.append(title_prev_dict)

# %%
# Print the list to confirm success
for item in text_data:
    print(item)
# Out:
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': 'News - Mars Exploration Program'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': 'MARS Planet Science'}
# {'text': '\n'}
# {'text': 'Exploration Program'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': 'The Red Planet'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': 'The Program'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': 'News & Events'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': 'Multimedia'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': 'Missions'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': 'More'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': 'News'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': 'Latest'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': 'All Categories'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': 'November 9, 2022'}
# {'text': '\n'}
# {'text': "NASA's MAVEN Observes Martian Light Show Caused by Major Solar Storm"}
# {'text': '\n'}
# {'text': 'For the first time in its eight years orbiting Mars, NASA’s MAVEN mission witnessed two different types of ultraviolet aurorae simultaneously, the result of solar storms that began on Aug. 27.'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': 'November 1, 2022'}
# {'text': '\n'}
# {'text': "NASA Prepares to Say 'Farewell' to InSight Spacecraft"}
# {'text': '\n'}
# {'text': 'A closer look at what goes into wrapping up the mission as the spacecraft’s power supply continues to dwindle.'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': 'October 28, 2022'}
# {'text': '\n'}
# {'text': 'NASA and ESA Agree on Next Steps to Return Mars Samples to Earth'}
# {'text': '\n'}
# {'text': 'The agency’s Perseverance rover will establish the first sample depot on Mars.'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': 'October 27, 2022'}
# {'text': '\n'}
# {'text': "NASA's InSight Lander Detects Stunning Meteoroid Impact on Mars"}
# {'text': '\n'}
# {'text': 'The agency’s lander felt the ground shake during the impact while cameras aboard the Mars Reconnaissance Orbiter spotted the yawning new crater from space.'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': 'October 21, 2022'}
# {'text': '\n'}
# {'text': 'NASA To Host Briefing on InSight, Mars Reconnaissance Orbiter Findings'}
# {'text': '\n'}
# {'text': 'Scientists from two Mars missions will discuss how they combined images and data for a major finding on the Red Planet.'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': 'October 20, 2022'}
# {'text': '\n'}
# {'text': 'Why NASA Is Trying To Crash Land on Mars'}
# {'text': '\n'}
# {'text': 'Like a car’s crumple zone, the experimental SHIELD lander is designed to absorb a hard impact.'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': 'October 19, 2022'}
# {'text': '\n'}
# {'text': 'Curiosity Mars Rover Reaches Long-Awaited Salty Region'}
# {'text': '\n'}
# {'text': 'After years of climbing, the Mars rover has arrived at a special region believed to have formed as Mars’ climate was drying.'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': 'October 12, 2022'}
# {'text': '\n'}
# {'text': 'Mars Mission Shields Up for Tests'}
# {'text': '\n'}
# {'text': 'Protecting Mars Sample Return spacecraft from micrometeorites requires high-caliber work.'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': 'October 7, 2022'}
# {'text': '\n'}
# {'text': "NASA's InSight Waits Out Dust Storm"}
# {'text': '\n'}
# {'text': 'InSight’s team is taking steps to help the solar-powered lander continue operating for as long as possible.'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': 'September 19, 2022'}
# {'text': '\n'}
# {'text': "NASA's InSight 'Hears' Its First Meteoroid Impacts on Mars"}
# {'text': '\n'}
# {'text': 'The Mars lander’s seismometer has picked up vibrations from four separate impacts in the past two years.'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': 'September 15, 2022'}
# {'text': '\n'}
# {'text': "NASA's Perseverance Rover Investigates Geologically Rich Mars Terrain"}
# {'text': '\n'}
# {'text': 'The latest findings provide greater detail on a region of the Red Planet that has a watery past and is yielding promising samples for the NASA-ESA Mars Sample Return campaign.'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': 'September 12, 2022'}
# {'text': '\n'}
# {'text': 'NASA to Host Briefing on Perseverance Mars Rover Mission Operations'}
# {'text': '\n'}
# {'text': 'Members of the mission will discuss the rover’s activities as it gathers samples in an ancient river delta.'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': 'August 25, 2022'}
# {'text': '\n'}
# {'text': "NASA's Perseverance Makes New Discoveries in Mars' Jezero Crater"}
# {'text': '\n'}
# {'text': 'The rover found that Jezero Crater’s floor is made up of volcanic rocks that have interacted with water.'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': 'August 5, 2022'}
# {'text': '\n'}
# {'text': "10 Years Since Landing, NASA's Curiosity Mars Rover Still Has Drive"}
# {'text': '\n'}
# {'text': 'Despite signs of wear, the intrepid spacecraft is about to start an exciting new chapter of its mission as it climbs a Martian mountain.'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': 'August 4, 2022'}
# {'text': '\n'}
# {'text': "SAM's Top 5 Discoveries Aboard NASA's Curiosity Rover at Mars"}
# {'text': '\n'}
# {'text': '“Selfie” of the Curiosity rover with inset showing the SAM instrument prior to installation on the rover.'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': 'More'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': 'You Might Also Like'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': 'NASA Marks 25 Years Since Pathfinder Touched Down on Mars'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': "NASA's Perseverance Rover Captures Video of Solar Eclipse on Mars"}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': 'NASA, UAE Mars Missions Agree to Share Science Data'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': 'The Red Planet'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': 'Dashboard'}
# {'text': '\n'}
# {'text': 'Science Goals'}
# {'text': '\n'}
# {'text': 'The Planet'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': 'The Program'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': 'Mission Statement'}
# {'text': '\n'}
# {'text': 'About the Program'}
# {'text': '\n'}
# {'text': 'Organization Why Mars?'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': 'Multimedia'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': 'Images'}
# {'text': '\n'}
# {'text': 'Videos'}
# {'text': '\n'}
# {'text': 'More Resources'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': 'Missions'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': 'Past'}
# {'text': '\n'}
# {'text': 'Present'}
# {'text': '\n'}
# {'text': 'Future'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': "Images and news content extracted from NASA's "}
# {'text': 'Mars News'}
# {'text': ' website on November 9, 2022.'}
# {'text': '\n         Images used in accordance with the '}
# {'text': 'JPL Image Use Policy'}
# {'text': '.'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': 'This site is operated by edX Boot Camps LLC for educational purposes only.  '}
# {'text': '\n            This is not a website endorsed by NASA. This website is intended only for internal academic purposes.'}
# {'text': '\n'}
# {'text': '\n'}
# {'text': '\n'}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': 'News - Mars Exploration Program'}
# {'title': 'News - Mars Exploration Program', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': 'MARS Planet Science'}
# {'title': 'MARS Planet Science', 'preview': ''}
# {'title': '', 'preview': 'Exploration Program'}
# {'title': 'Exploration Program', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': 'The Red Planet'}
# {'title': 'The Red Planet', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': 'The Program'}
# {'title': 'The Program', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': 'News & Events'}
# {'title': 'News & Events', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': 'Multimedia'}
# {'title': 'Multimedia', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': 'Missions'}
# {'title': 'Missions', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': 'More'}
# {'title': 'More', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': 'News'}
# {'title': 'News', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': 'Latest'}
# {'title': 'Latest', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': 'All Categories'}
# {'title': 'All Categories', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': 'November 9, 2022'}
# {'title': 'November 9, 2022', 'preview': ''}
# {'title': '', 'preview': "NASA's MAVEN Observes Martian Light Show Caused by Major Solar Storm"}
# {'title': "NASA's MAVEN Observes Martian Light Show Caused by Major Solar Storm", 'preview': ''}
# {'title': '', 'preview': 'For the first time in its eight years orbiting Mars, NASA’s MAVEN mission witnessed two different types of ultraviolet aurorae simultaneously, the result of solar storms that began on Aug. 27.'}
# {'title': 'For the first time in its eight years orbiting Mars, NASA’s MAVEN mission witnessed two different types of ultraviolet aurorae simultaneously, the result of solar storms that began on Aug. 27.', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': 'November 1, 2022'}
# {'title': 'November 1, 2022', 'preview': ''}
# {'title': '', 'preview': "NASA Prepares to Say 'Farewell' to InSight Spacecraft"}
# {'title': "NASA Prepares to Say 'Farewell' to InSight Spacecraft", 'preview': ''}
# {'title': '', 'preview': 'A closer look at what goes into wrapping up the mission as the spacecraft’s power supply continues to dwindle.'}
# {'title': 'A closer look at what goes into wrapping up the mission as the spacecraft’s power supply continues to dwindle.', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': 'October 28, 2022'}
# {'title': 'October 28, 2022', 'preview': ''}
# {'title': '', 'preview': 'NASA and ESA Agree on Next Steps to Return Mars Samples to Earth'}
# {'title': 'NASA and ESA Agree on Next Steps to Return Mars Samples to Earth', 'preview': ''}
# {'title': '', 'preview': 'The agency’s Perseverance rover will establish the first sample depot on Mars.'}
# {'title': 'The agency’s Perseverance rover will establish the first sample depot on Mars.', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': 'October 27, 2022'}
# {'title': 'October 27, 2022', 'preview': ''}
# {'title': '', 'preview': "NASA's InSight Lander Detects Stunning Meteoroid Impact on Mars"}
# {'title': "NASA's InSight Lander Detects Stunning Meteoroid Impact on Mars", 'preview': ''}
# {'title': '', 'preview': 'The agency’s lander felt the ground shake during the impact while cameras aboard the Mars Reconnaissance Orbiter spotted the yawning new crater from space.'}
# {'title': 'The agency’s lander felt the ground shake during the impact while cameras aboard the Mars Reconnaissance Orbiter spotted the yawning new crater from space.', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': 'October 21, 2022'}
# {'title': 'October 21, 2022', 'preview': ''}
# {'title': '', 'preview': 'NASA To Host Briefing on InSight, Mars Reconnaissance Orbiter Findings'}
# {'title': 'NASA To Host Briefing on InSight, Mars Reconnaissance Orbiter Findings', 'preview': ''}
# {'title': '', 'preview': 'Scientists from two Mars missions will discuss how they combined images and data for a major finding on the Red Planet.'}
# {'title': 'Scientists from two Mars missions will discuss how they combined images and data for a major finding on the Red Planet.', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': 'October 20, 2022'}
# {'title': 'October 20, 2022', 'preview': ''}
# {'title': '', 'preview': 'Why NASA Is Trying To Crash Land on Mars'}
# {'title': 'Why NASA Is Trying To Crash Land on Mars', 'preview': ''}
# {'title': '', 'preview': 'Like a car’s crumple zone, the experimental SHIELD lander is designed to absorb a hard impact.'}
# {'title': 'Like a car’s crumple zone, the experimental SHIELD lander is designed to absorb a hard impact.', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': 'October 19, 2022'}
# {'title': 'October 19, 2022', 'preview': ''}
# {'title': '', 'preview': 'Curiosity Mars Rover Reaches Long-Awaited Salty Region'}
# {'title': 'Curiosity Mars Rover Reaches Long-Awaited Salty Region', 'preview': ''}
# {'title': '', 'preview': 'After years of climbing, the Mars rover has arrived at a special region believed to have formed as Mars’ climate was drying.'}
# {'title': 'After years of climbing, the Mars rover has arrived at a special region believed to have formed as Mars’ climate was drying.', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': 'October 12, 2022'}
# {'title': 'October 12, 2022', 'preview': ''}
# {'title': '', 'preview': 'Mars Mission Shields Up for Tests'}
# {'title': 'Mars Mission Shields Up for Tests', 'preview': ''}
# {'title': '', 'preview': 'Protecting Mars Sample Return spacecraft from micrometeorites requires high-caliber work.'}
# {'title': 'Protecting Mars Sample Return spacecraft from micrometeorites requires high-caliber work.', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': 'October 7, 2022'}
# {'title': 'October 7, 2022', 'preview': ''}
# {'title': '', 'preview': "NASA's InSight Waits Out Dust Storm"}
# {'title': "NASA's InSight Waits Out Dust Storm", 'preview': ''}
# {'title': '', 'preview': 'InSight’s team is taking steps to help the solar-powered lander continue operating for as long as possible.'}
# {'title': 'InSight’s team is taking steps to help the solar-powered lander continue operating for as long as possible.', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': 'September 19, 2022'}
# {'title': 'September 19, 2022', 'preview': ''}
# {'title': '', 'preview': "NASA's InSight 'Hears' Its First Meteoroid Impacts on Mars"}
# {'title': "NASA's InSight 'Hears' Its First Meteoroid Impacts on Mars", 'preview': ''}
# {'title': '', 'preview': 'The Mars lander’s seismometer has picked up vibrations from four separate impacts in the past two years.'}
# {'title': 'The Mars lander’s seismometer has picked up vibrations from four separate impacts in the past two years.', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': 'September 15, 2022'}
# {'title': 'September 15, 2022', 'preview': ''}
# {'title': '', 'preview': "NASA's Perseverance Rover Investigates Geologically Rich Mars Terrain"}
# {'title': "NASA's Perseverance Rover Investigates Geologically Rich Mars Terrain", 'preview': ''}
# {'title': '', 'preview': 'The latest findings provide greater detail on a region of the Red Planet that has a watery past and is yielding promising samples for the NASA-ESA Mars Sample Return campaign.'}
# {'title': 'The latest findings provide greater detail on a region of the Red Planet that has a watery past and is yielding promising samples for the NASA-ESA Mars Sample Return campaign.', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': 'September 12, 2022'}
# {'title': 'September 12, 2022', 'preview': ''}
# {'title': '', 'preview': 'NASA to Host Briefing on Perseverance Mars Rover Mission Operations'}
# {'title': 'NASA to Host Briefing on Perseverance Mars Rover Mission Operations', 'preview': ''}
# {'title': '', 'preview': 'Members of the mission will discuss the rover’s activities as it gathers samples in an ancient river delta.'}
# {'title': 'Members of the mission will discuss the rover’s activities as it gathers samples in an ancient river delta.', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': 'August 25, 2022'}
# {'title': 'August 25, 2022', 'preview': ''}
# {'title': '', 'preview': "NASA's Perseverance Makes New Discoveries in Mars' Jezero Crater"}
# {'title': "NASA's Perseverance Makes New Discoveries in Mars' Jezero Crater", 'preview': ''}
# {'title': '', 'preview': 'The rover found that Jezero Crater’s floor is made up of volcanic rocks that have interacted with water.'}
# {'title': 'The rover found that Jezero Crater’s floor is made up of volcanic rocks that have interacted with water.', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': 'August 5, 2022'}
# {'title': 'August 5, 2022', 'preview': ''}
# {'title': '', 'preview': "10 Years Since Landing, NASA's Curiosity Mars Rover Still Has Drive"}
# {'title': "10 Years Since Landing, NASA's Curiosity Mars Rover Still Has Drive", 'preview': ''}
# {'title': '', 'preview': 'Despite signs of wear, the intrepid spacecraft is about to start an exciting new chapter of its mission as it climbs a Martian mountain.'}
# {'title': 'Despite signs of wear, the intrepid spacecraft is about to start an exciting new chapter of its mission as it climbs a Martian mountain.', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': 'August 4, 2022'}
# {'title': 'August 4, 2022', 'preview': ''}
# {'title': '', 'preview': "SAM's Top 5 Discoveries Aboard NASA's Curiosity Rover at Mars"}
# {'title': "SAM's Top 5 Discoveries Aboard NASA's Curiosity Rover at Mars", 'preview': ''}
# {'title': '', 'preview': '“Selfie” of the Curiosity rover with inset showing the SAM instrument prior to installation on the rover.'}
# {'title': '“Selfie” of the Curiosity rover with inset showing the SAM instrument prior to installation on the rover.', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': 'More'}
# {'title': 'More', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': 'You Might Also Like'}
# {'title': 'You Might Also Like', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': 'NASA Marks 25 Years Since Pathfinder Touched Down on Mars'}
# {'title': 'NASA Marks 25 Years Since Pathfinder Touched Down on Mars', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': "NASA's Perseverance Rover Captures Video of Solar Eclipse on Mars"}
# {'title': "NASA's Perseverance Rover Captures Video of Solar Eclipse on Mars", 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': 'NASA, UAE Mars Missions Agree to Share Science Data'}
# {'title': 'NASA, UAE Mars Missions Agree to Share Science Data', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': 'The Red Planet'}
# {'title': 'The Red Planet', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': 'Dashboard'}
# {'title': 'Dashboard', 'preview': ''}
# {'title': '', 'preview': 'Science Goals'}
# {'title': 'Science Goals', 'preview': ''}
# {'title': '', 'preview': 'The Planet'}
# {'title': 'The Planet', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': 'The Program'}
# {'title': 'The Program', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': 'Mission Statement'}
# {'title': 'Mission Statement', 'preview': ''}
# {'title': '', 'preview': 'About the Program'}
# {'title': 'About the Program', 'preview': ''}
# {'title': '', 'preview': 'Organization Why Mars?'}
# {'title': 'Organization Why Mars?', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': 'Multimedia'}
# {'title': 'Multimedia', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': 'Images'}
# {'title': 'Images', 'preview': ''}
# {'title': '', 'preview': 'Videos'}
# {'title': 'Videos', 'preview': ''}
# {'title': '', 'preview': 'More Resources'}
# {'title': 'More Resources', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': 'Missions'}
# {'title': 'Missions', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': 'Past'}
# {'title': 'Past', 'preview': ''}
# {'title': '', 'preview': 'Present'}
# {'title': 'Present', 'preview': ''}
# {'title': '', 'preview': 'Future'}
# {'title': 'Future', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': "Images and news content extracted from NASA's"}
# {'title': "Images and news content extracted from NASA's", 'preview': 'Mars News'}
# {'title': 'Mars News', 'preview': 'website on November 9, 2022.'}
# {'title': 'website on November 9, 2022.', 'preview': 'Images used in accordance with the'}
# {'title': 'Images used in accordance with the', 'preview': 'JPL Image Use Policy'}
# {'title': 'JPL Image Use Policy', 'preview': '.'}
# {'title': '.', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': 'This site is operated by edX Boot Camps LLC for educational purposes only.'}
# {'title': 'This site is operated by edX Boot Camps LLC for educational purposes only.', 'preview': 'This is not a website endorsed by NASA. This website is intended only for internal academic purposes.'}
# {'title': 'This is not a website endorsed by NASA. This website is intended only for internal academic purposes.', 'preview': ''}
# {'title': '', 'preview': ''}
# {'title': '', 'preview': ''}

# %%
browser.quit()
